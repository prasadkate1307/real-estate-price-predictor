# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("D:\pc\PROGRAMMING\DataScience\Datasets\RealEstate(gurgaon).csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\HP\AppData\Local\Temp\ipykernel_5576\3896875041.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv("D:\pc\PROGRAMMING\DataScience\Datasets\RealEstate(gurgaon).csv")
#    F/H sector                          society  price   rate  area  bedRoom  \
# 0    1     81         signature global city 81   0.82   8639   949        2
# 1    0     50      unitech nirvana birch court  11.95  36883  3240        3
# 2    1    107          signature global solera   0.28   5674   493        2
# 3    0      5                              NaN   3.50  14787  2367        5
# 4    0      3  ashok vihar phase iii extension   0.40   8889   450        7
#
#    bathroom  balcony           additionalRoom  \
# 0         2        3                      0.0
# 1         3        2  Study Room,Servant Room
# 2         2        2                      0.0
# ...

# %%
df[df.duplicated()]
# Out:
#       F/H sector                   society  price   rate  area  bedRoom  \
# 83      1     12            bhagwati sadan   1.15   5500  2091        3
# 292     1     35             ashiana anmol   0.88  11125   791        2
# 464     1    109            ats tourmaline   2.30   8897  2585        3
# 484     1     92             sare petioles   1.30   6373  2040        4
# 532     1     28               essel tower   2.20  12500  1760        3
# ...   ...    ...                       ...    ...    ...   ...      ...
# 3876    0    70A          bptp visionnaire   5.40  20690  2610        4
# 3880    0     48        vipul tatvam villa   8.40  21000  4000        4
# 3894    1    10A  maxworth city residences   0.90   7083  1271        2
# 3898    1    36A            avl 36 gurgaon   0.75   7500  1000        2
# 3904    0     43                       NaN   5.75  29716  1935        4
#
#       bathroom  balcony                                 additionalRoom  \
# ...

# %%
df[df['society']=='bhagwati sadan']
# Out:
#       F/H sector         society  price  rate  area  bedRoom  bathroom  \
# 45      1     12  bhagwati sadan   1.15  5500  2091        3         4
# 83      1     12  bhagwati sadan   1.15  5500  2091        3         4
# 2951    1    12A  bhagwati sadan   1.15  5750  2000        3         4
#
#       balcony additionalRoom  \
# 45          2            2.0
# 83          2            2.0
# 2951        2            3.0
#
#                                                 address  floorNum  \
# 45    Mianwali Colony, Sector 12, Gurgaon, Sector 12...       2.0
# 83    Mianwali Colony, Sector 12, Gurgaon, Sector 12...       2.0
# 2951  Bhagwati Sadan, Plot No 308, Sector 12A Gurgao...       2.0
#
#      agePossession                                    nearbyLocations  \
# 45    10+ Year Old  ['Hanuman Mandir', 'Dental Health Centre', 'No...
# 83    10+ Year Old  ['Hanuman Mandir', 'Dental Health Centre', 'No...
# 2951  10+ Year Old  ['Hanuman Mandir', 'Dental Health Centre', 'No...
#
# ...

# %%
df.drop(columns=[df['level_0'],df['index']],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.drop(columns=[df['level_0'],df['index']],inplace=True)
#
# File D:\anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df.head()
# Out:
#    F/H sector                          society  price   rate  area  bedRoom  \
# 0    1     81         signature global city 81   0.82   8639   949        2
# 1    0     50      unitech nirvana birch court  11.95  36883  3240        3
# 2    1    107          signature global solera   0.28   5674   493        2
# 3    0      5                              NaN   3.50  14787  2367        5
# 4    0      3  ashok vihar phase iii extension   0.40   8889   450        7
#
#    bathroom  balcony           additionalRoom  \
# 0         2        3                      0.0
# 1         3        2  Study Room,Servant Room
# 2         2        2                      0.0
# 3         4        2        Pooja Room,Others
# 4         4        3               Pooja Room
#
#                                              address  floorNum  \
# 0     Sector 81, Sector 81 Gurgaon, Gurgaon, Haryana       2.0
# 1                  Nirvana Country, Gurgaon, Haryana       1.0
# ...

# %%
df.describe()
# Out:
#                F/H        price           rate          area      bedRoom  \
# count  3909.000000  3909.000000    3909.000000  3.909000e+03  3909.000000
# mean      0.759785     2.492154   13996.770274  4.670846e+03     3.357125
# std       0.427269     2.941270   23279.790951  1.180656e+05     2.002139
# min       0.000000     0.070000       2.000000  4.500000e+01     1.000000
# 25%       1.000000     0.910000    6808.000000  1.200000e+03     2.000000
# 50%       1.000000     1.500000    9000.000000  1.703000e+03     3.000000
# 75%       1.000000     2.700000   13870.000000  2.291000e+03     4.000000
# max       1.000000    31.500000  600000.000000  7.250000e+06    36.000000
#
#           bathroom      balcony     floorNum
# count  3909.000000  3909.000000  3753.000000
# mean      3.407009     2.388079     6.934985
# std       2.042878     0.872983     5.982030
# min       1.000000     0.000000     0.000000
# 25%       2.000000     2.000000     3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   F/H              3909 non-null   int64
#  1   sector           3904 non-null   object
#  2   society          3357 non-null   object
#  3   price            3909 non-null   float64
#  4   rate             3909 non-null   int64
#  5   area             3909 non-null   int64
#  6   bedRoom          3909 non-null   int64
#  7   bathroom         3909 non-null   int64
#  8   balcony          3909 non-null   int64
#  9   additionalRoom   3541 non-null   object
#  10  address          3898 non-null   object
#  11  floorNum         3753 non-null   float64
#  12  agePossession    3908 non-null   object
#  13  nearbyLocations  3713 non-null   object
#  14  furnishDetails   2891 non-null   object
#  15  features         3219 non-null   object
# dtypes: float64(2), int64(6), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# F/H                   0
# sector                0
# society             551
# price                 0
# rate                  0
# area                  0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom      368
# address              11
# floorNum            156
# agePossession         1
# nearbyLocations     196
# furnishDetails     1018
# features            690
# dtype: int64

# %%
df[df['sector'].isnull()]
# Out:
# Empty DataFrame
# Columns: [F/H, sector, society, price, rate, area, bedRoom, bathroom, balcony, additionalRoom, address, floorNum, agePossession, nearbyLocations, furnishDetails, features]
# Index: []

# %%
addresses = [
    'B Block Sushant Lok Phase 1, Gurgaon, Haryana',
    'Sushant Lok, B Block Sushant Lok Phase 1, Gurg...'
]
df.loc[df['address'].isin(addresses) & df['sector'].isnull(),'sector']=43

# %%
df.loc[df['address'].str.contains('Suncity, Gurgaon, Haryana') & df['sector'].isnull(),'sector']=54

# %%
df.loc[1896]=df.loc[1896].fillna(43)

# %% [markdown]
# #### ADDRESS

# %%
df[df['address'].isnull()]
# Out:
#       F/H sector                  society  price   rate  area  bedRoom  \
# 406     0      3                      NaN   0.38   8444   450        1
# 605     1     79       supertech araville   0.90   5883  1530        2
# 1720    0     11           not applicable   2.20  12222  1800        4
# 2142    0     54         suncity township   2.00  30968   646        9
# 2159    0     12                      NaN   1.72  11111  1548        6
# 2463    1    104               hero homes   1.20  17548   684        2
# 2759    1      3          vidya apartment   0.22   4210   523        2
# 2833    0    104     shri shyam residency   0.62  12400   500        3
# 3033    1     83   vatika lifestyle homes   1.30   4545  2860        3
# 3745    1    111   tashee capital gateway   0.96   6500  1477        2
# 3843    1     92  sare green parc phase 3   1.08   5150  2097        4
#
#       bathroom  balcony         additionalRoom address  floorNum  \
# ...

# %% [markdown]
# #### Price

# %%
df['price'].describe()
# Out:
# count    3909.000000
# mean        2.492154
# std         2.941270
# min         0.070000
# 25%         0.910000
# 50%         1.500000
# 75%         2.700000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.distplot(df['price'],kde=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5576\3167317642.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'],kde=True)
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ### Rate And Area

# %%
df.rename(columns={'area':'total_area(sqft)','rate':'price_per_sqft'},inplace=True)

# %%
df.columns
# Out:
# Index(['F/H', 'sector', 'society', 'price', 'price_per_sqft',
#        'total_area(sqft)', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'address', 'floorNum', 'agePossession', 'nearbyLocations',
#        'furnishDetails', 'features'],
#       dtype='object')

# %%
df.sample(3)
# Out:
#       F/H sector              society  price  price_per_sqft  \
# 664     1    88A  adani aangan arcade   0.45            7194
# 6       1     82    mapsko casa bella   0.86            8120
# 1461    1     69         tulip violet   1.76            9513
#
#       total_area(sqft)  bedRoom  bathroom  balcony additionalRoom  \
# 664                626        2         2        1            0.0
# 6                 1059        3         3        3            1.0
# 1461              1850        3         4        2            0.0
#
#                                                 address  floorNum  \
# 664   Tower A-4, Flat No. 804, Sector 88A Gurgaon, G...       8.0
# 6        Sector-82, Sector 82 Gurgaon, Gurgaon, Haryana       5.0
# 1461           004, Sector 69 Gurgaon, Gurgaon, Haryana       NaN
#
#          agePossession                                    nearbyLocations  \
# 664    0 to 1 Year Old  ['Reliance Trends Newtown Square Mall', 'Patau...
# ...

# %% [markdown]
# ### BEDROOM, BATHROOM, BALCONY

# %%
df['bedRoom'].value_counts() ## yeah there can be more than 10 bhk also as they are villa/houses also i search it 
##  on 99 acres they are not outliers
# Out:
# bedRoom
# 3     1575
# 2     1018
# 4      702
# 5      211
# 1      138
# 6       84
# 9       43
# 8       34
# 7       29
# 12      28
# 10      21
# 16      11
# 13       4
# 19       2
# 11       2
# 18       2
# 20       1
# 34       1
# 14       1
# 21       1
# 36       1
# Name: count, dtype: int64

# %%
df[df['bedRoom']>10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df['bedRoom']>10]
#
# NameError: name 'df' is not defined

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3    2336
# 2     960
# 1     407
# 0     206
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows',None)
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# 0.0                                              1287
# 1.0                                              1246
# 2.0                                               322
# Servant Room                                       80
# Pooja Room,Study Room,Servant Room,Store Room      62
# 3.0                                                58
# Others                                             57
# 4.0                                                57
# Pooja Room                                         38
# Pooja Room,Study Room,Servant Room                 33
# Store Room                                         31
# Pooja Room,Study Room,Servant Room,Others          27
# Pooja Room,Servant Room                            24
# Study Room,Servant Room                            18
# Study Room                                         17
# Servant Room,Store Room                            12
# Pooja Room,Others                                  11
# ...

# %%
df[df['additionalRoom'].isnull()].head(4)
# Out:
#     F/H sector society  price  price_per_sqft  total_area(sqft)  bedRoom  \
# 25    0     12     NaN   2.00           14954              1337        3
# 26    0     12     NaN   6.00          315789               190        9
# 28    0     11     NaN   3.50           15555              2250       10
# 51    0     39     NaN   0.34            7555               450        1
#
#     bathroom  balcony additionalRoom  \
# 25         1        0            NaN
# 26         6        2            NaN
# 28         1        0            NaN
# 51         1        1            NaN
#
#                                               address  floorNum  \
# 25                          Manesar, Gurgaon, Haryana       3.0
# 26  Near Sadar Bazar Gurgaon, Jacobpura, Gurgaon, ...       2.0
# 28  Shivaji Nagar, Sector 11, Gurgaon, Sector 11 G...       1.0
# 51  Jharsa Village, Sector 39, Gurgaon, Sector 39 ...       1.0
#
#        agePossession                                    nearbyLocations  \
# ...

# %%
df['additionalRoom']=df['additionalRoom'].fillna(0.0)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Floor No.

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 3.0     545
# 2.0     539
# 1.0     388
# 4.0     329
# 8.0     200
# 6.0     187
# 7.0     187
# 10.0    186
# 5.0     181
# 9.0     170
# 12.0    162
# 14.0    120
# 11.0    113
# 15.0     83
# 16.0     54
# 17.0     51
# 13.0     43
# 18.0     38
# 19.0     33
# 20.0     25
# 21.0     16
# 23.0     14
# 22.0     14
# 24.0     11
# 25.0      9
# 27.0      8
# 30.0      5
# 0.0       5
# 26.0      5
# 28.0      4
# 33.0      4
# 31.0      4
# 29.0      3
# 32.0      2
# 40.0      2
# 35.0      2
# 39.0      2
# 34.0      2
# 43.0      2
# 44.0      1
# 45.0      1
# 41.0      1
# 51.0      1
# 38.0      1
# Name: count, dtype: int64

# %%
df['F/H'].value_counts()
# Out:
# F/H
# 1    2970
# 0     939
# Name: count, dtype: int64

# %%
df[df['floorNum'].isnull()].sample(5)
# Out:
#       F/H sector                  society  price  price_per_sqft  \
# 2877    1    108          raheja vedaanta   1.00            4854
# 411     1     33          eldeco accolade   1.20            8043
# 3310    1    107  signature global solera   0.28            5828
# 3298    1     86            pyramid elite   0.46              79
# 3661    1     90              green court   0.47            6811
#
#       total_area(sqft)  bedRoom  bathroom  balcony additionalRoom  \
# 2877              2060        2         2        2            0.0
# 411               1492        2         2        2            1.0
# 3310               480        2         2        2            0.0
# 3298             58228        2         2        1            0.0
# 3661               690        2         2        1            0.0
#
#                                                address  floorNum  \
# 2877  Sector 108, Sector 108 Gurgaon, Gurgaon, Haryana       NaN
# ...

# %%
df.to_csv('Real_estate_DataCleaning')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_csv('Real_estate_DataCleaning')
#
# NameError: name 'df' is not defined
