# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('Real_estate_DataCleaning_v1.csv',index_col=0)

# %%
df.head()
# Out:
#    F/H sector                          society  price  price_per_sqft  \
# 0    1     81         signature global city 81   0.82            8639
# 1    0     50      unitech nirvana birch court  11.95           36883
# 2    1    107          signature global solera   0.28            5674
# 3    0      5                              NaN   3.50           14787
# 4    0      3  ashok vihar phase iii extension   0.40            8889
#
#    total_area(sqft)  bedRoom  bathroom  balcony           additionalRoom  \
# 0               949        2         2        3                      0.0
# 1              3240        3         3        2  Study Room,Servant Room
# 2               493        2         2        2                      0.0
# 3              2367        5         4        2        Pooja Room,Others
# 4               450        7         4        3               Pooja Room
#
#                                              address  floorNum  \
# ...

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 3.0     545
# 2.0     539
# 1.0     388
# 4.0     329
# 8.0     200
# 6.0     187
# 7.0     187
# 10.0    186
# 5.0     181
# 9.0     170
# 12.0    162
# 14.0    120
# 11.0    113
# 15.0     83
# 16.0     54
# 17.0     51
# 13.0     43
# 18.0     38
# 19.0     33
# 20.0     25
# 21.0     16
# 23.0     14
# 22.0     14
# 24.0     11
# 25.0      9
# 27.0      8
# 30.0      5
# 0.0       5
# 26.0      5
# 28.0      4
# 33.0      4
# 31.0      4
# 29.0      3
# 32.0      2
# 40.0      2
# 35.0      2
# 39.0      2
# 34.0      2
# 43.0      2
# 44.0      1
# 45.0      1
# 41.0      1
# 51.0      1
# 38.0      1
# Name: count, dtype: int64

# %% [markdown]
# ### ADDRESS

# %%
df[df['society'].isnull() & df['address'].isnull()]
# Out:
#       F/H sector society  price  price_per_sqft  total_area(sqft)  bedRoom  \
# 406     0      3     NaN   0.38            8444               450        1
# 2159    0     12     NaN   1.72           11111              1548        6
#
#       bathroom  balcony additionalRoom address  floorNum     agePossession  \
# 406          1        1              0     NaN       1.0  5 to 10 Year Old
# 2159         3        1         Others     NaN       2.0      10+ Year Old
#
#                                         nearbyLocations furnishDetails  \
# 406   ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...            NaN
# 2159  ['Hanuman Mandir', 'Sharma Hospital Gurgaon', ...            NaN
#
#                     features
# 406   ['Recently Renovated']
# 2159                     NaN

# %%
df.drop(index=[406,2159],inplace=True)

# %%
df[df['address'].isnull()]
# Out:
#       F/H sector                  society  price  price_per_sqft  \
# 605     1     79       supertech araville   0.90            5883
# 1720    0     11           not applicable   2.20           12222
# 2142    0     54         suncity township   2.00           30968
# 2463    1    104               hero homes   1.20           17548
# 2759    1      3          vidya apartment   0.22            4210
# 2833    0    104     shri shyam residency   0.62           12400
# 3033    1     83   vatika lifestyle homes   1.30            4545
# 3745    1    111   tashee capital gateway   0.96            6500
# 3843    1     92  sare green parc phase 3   1.08            5150
#
#       total_area(sqft)  bedRoom  bathroom  balcony         additionalRoom  \
# 605               1530        2         2        3                    1.0
# 1720              1800        4         3        2  Pooja Room,Study Room
# 2142               646        9         9        3           Servant Room
# ...

# %%
df.loc[2142,'address']='Sector 54, Golf Course Road, Gurugram, Haryana'
df.loc[2463,'address']='Sector 104, along the Dwarka Expressway, Gurugram, Haryana'
df.loc[3033,'address']='Vatika India Next, Sector 83, Gurugram, Haryana'
df.loc[3745,'address']='Sector 111, Dwarka Expressway, Gurugram'
df.loc[3843,'address']='Sector 92, Gurgaon, Haryana'
df.drop(index=[2833,2759,1720],inplace=True)

# %%
df[df['society']=='supertech araville']
# Out:
#       F/H sector             society  price  price_per_sqft  total_area(sqft)  \
# 128     1     79  supertech araville   0.71            6061              1171
# 319     1     79  supertech araville   0.78            6024              1295
# 605     1     79  supertech araville   0.90            5883              1530
# 800     1     79  supertech araville   0.71            5522              1286
# 1359    1     79  supertech araville   1.45            7455              1945
# 1767    1     79  supertech araville   0.78            6023              1295
# 1880    1     79  supertech araville   1.35            9000              1500
# 2121    1     79  supertech araville   0.80            6178              1295
# 2280    1     79  supertech araville   0.71            6061              1171
# 2539    1     79  supertech araville   0.83            5424              1530
# 2610    1     79  supertech araville   1.10            5641              1950
# ...

# %%
df.loc[605,'address']='Sector 79, Naurangpur, Gurugram, Haryana, 122004, India'

# %%
df[df['address'].isnull()]  ## Removed and modifies all missing values in address
# Out:
# Empty DataFrame
# Columns: [F/H, sector, society, price, price_per_sqft, total_area(sqft), bedRoom, bathroom, balcony, additionalRoom, address, floorNum, agePossession, nearbyLocations, furnishDetails, features]
# Index: []

# %%
df['society'].isnull().sum()
# Out:
# 550

# %% [markdown]
# ### Age Possession

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3904 entries, 0 to 3908
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   F/H               3904 non-null   int64
#  1   sector            3899 non-null   object
#  2   society           3354 non-null   object
#  3   price             3904 non-null   float64
#  4   price_per_sqft    3904 non-null   int64
#  5   total_area(sqft)  3904 non-null   int64
#  6   bedRoom           3904 non-null   int64
#  7   bathroom          3904 non-null   int64
#  8   balcony           3904 non-null   int64
#  9   additionalRoom    3904 non-null   object
#  10  address           3904 non-null   object
#  11  floorNum          3748 non-null   float64
#  12  agePossession     3903 non-null   object
#  13  nearbyLocations   3708 non-null   object
#  14  furnishDetails    2888 non-null   object
#  15  features          3215 non-null   object
# ...

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# 1 to 5 Year Old       1686
# 5 to 10 Year Old       599
# 0 to 1 Year Old        543
# undefined              354
# 10+ Year Old           345
# within 1 year          152
# Under Construction      87
# Within 6 months         69
# within 2-3 years        42
# Within 3 months         26
# Name: count, dtype: int64

# %%
index_list=df[df['agePossession'].str.contains('-',na=False,case=False)].index.tolist()

# %%
index_list
# Out:
# [15,
#  52,
#  56,
#  57,
#  69,
#  93,
#  94,
#  104,
#  111,
#  157,
#  193,
#  227,
#  249,
#  311,
#  348,
#  374,
#  385,
#  442,
#  444,
#  463,
#  488,
#  519,
#  576,
#  615,
#  639,
#  685,
#  698,
#  699,
#  783,
#  813,
#  922,
#  929,
#  955,
#  972,
#  1045,
#  1068,
#  1189,
#  1241,
#  1242,
#  1243,
#  1246,
#  1250,
#  1262,
#  1378,
#  1414,
#  1467,
#  1503,
#  1504,
#  1520,
#  1541,
#  1558,
#  1575,
#  1597,
#  1607,
#  1618,
#  1632,
#  1642,
#  1697,
#  1703,
#  1741,
#  1763,
#  1769,
#  1785,
#  1788,
#  1856,
#  1876,
#  1899,
#  1932,
#  1966,
#  1994,
#  2010,
#  2021,
#  2055,
#  2062,
#  2149,
#  2158,
#  2172,
#  2190,
#  2197,
#  2202,
#  2208,
#  2217,
#  2249,
#  2277,
#  2359,
#  2390,
#  2393,
#  2410,
#  2459,
#  2463,
#  2512,
#  2564,
#  2565,
#  2613,
#  2649,
#  2693,
#  2694,
#  2735,
#  2744,
#  2745,
#  2752,
#  2760,
#  2805,
#  2865,
#  2866,
#  2869,
#  2890,
#  2912,
#  2927,
#  2969,
#  2976,
#  2994,
#  3057,
#  3060,
#  3067,
# ...

# %%
df.loc[index_list,'agePossession']='within 1 year'

# %%
df.loc[df[df['agePossession'].str.contains('By',na=False,case=False)].index.tolist(),'agePossession']='within 2-3 years'

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### Floor Num

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 3.0     545
# 2.0     537
# 1.0     385
# 4.0     329
# 8.0     200
# 6.0     187
# 7.0     187
# 10.0    186
# 5.0     181
# 9.0     170
# 12.0    162
# 14.0    120
# 11.0    113
# 15.0     83
# 16.0     54
# 17.0     51
# 13.0     43
# 18.0     38
# 19.0     33
# 20.0     25
# 21.0     16
# 23.0     14
# 22.0     14
# 24.0     11
# 25.0      9
# 27.0      8
# 30.0      5
# 0.0       5
# 26.0      5
# 28.0      4
# 33.0      4
# 31.0      4
# 29.0      3
# 32.0      2
# 40.0      2
# 35.0      2
# 39.0      2
# 34.0      2
# 43.0      2
# 44.0      1
# 45.0      1
# 41.0      1
# 51.0      1
# 38.0      1
# Name: count, dtype: int64

# %% [markdown]
# ### Society

# %%
df[(df['society'].isnull()) & (df['F/H']==0)]
# Out:
#       index  F/H sector society  price  price_per_sqft  total_area(sqft)  \
# 3         3    0      5     NaN   3.50           14787              2367
# 25       25    0     12     NaN   2.00           14954              1337
# 26       26    0     12     NaN   6.00          315789               190
# 27       27    0     55     NaN   5.00           44444              1125
# 28       28    0     11     NaN   3.50           15555              2250
# ...     ...  ...    ...     ...    ...             ...               ...
# 3868   3873    0     12     NaN   0.38            4222               900
# 3886   3891    0     49     NaN   4.45           15451              2880
# 3890   3895    0      7     NaN   0.45            5000               900
# 3898   3903    0      8     NaN   0.63            7875               800
# 3899   3904    0     43     NaN   5.75           29716              1935
#
#       bedRoom  bathroom  balcony  \
# 3           5         4        2
# ...

# %%
df['society'].isnull().sum()
# Out:
# 550

# %%
df['society']=df['society'].fillna('indepedent')

# %%
df['society'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Furnish Details

# %%
df['furnishDetails'].value_counts()
# Out:
# furnishDetails
# Unfurnished                                                                                                                                                                                                                                                             1016
# []                                                                                                                                                                                                                                                                       431
# ['1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']     208
# ...

# %%
df['furnishDetails']=df['furnishDetails'].fillna('Unfurnished')

# %%
df['features'].value_counts()
# Out:
# features
# ['Feng Shui / Vaastu Compliant', 'Security / Fire Alarm', 'Intercom Facility', 'Lift(s)', 'Maintenance Staff', 'Water Storage', 'Park', 'Visitor Parking']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              286
# ...

# %% [markdown]
# ### WE HAVE TO DO FEATURE ENG ON furnishDetails(classify in semifurnish,furnished) , features(convert it into type of luxury on basis of features),agePossession(new, relatively new,old,moderately old,under construction),additional rooms

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.sample()
# Out:
#       F/H sector             society  price  price_per_sqft  total_area(sqft)  \
# 3292    1     33  godrej nature plus   1.55            9955              1557
#
#       bedRoom  bathroom  balcony additionalRoom  \
# 3292        3         2        3            0.0
#
#                                 address  floorNum    agePossession  \
# 3292  Sector-33 Sohna, Gurgaon, Haryana       8.0  Within 6 months
#
#                                         nearbyLocations furnishDetails  \
# 3292  ['Signature Global Infinity Mall Sohna', 'Bads...             []
#
#                                                features
# 3292  ['Feng Shui / Vaastu Compliant', 'Security / F...

# %%
df.to_csv('Real_estate_DataCleaning_v2.csv',index=False)
